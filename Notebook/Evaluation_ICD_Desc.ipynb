# %%
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# # RNN

# %%
train_loss_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/train_loss.pth")
train_accuracy_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/train_accuracy.pth")
train_f1score_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/train_f1score.pth")
train_precision_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/train_precision.pth")
train_recall_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/train_recall.pth")

test_loss_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/test_loss.pth")
test_accuracy_rnn = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/test_accuracy.pth')
test_f1score_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/test_f1score.pth")
test_precison_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/test_precision.pth")
test_recall_rnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/RNN/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1520749937.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_rnn)), train_accuracy_rnn, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of RNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_rnn)), train_precision_rnn, label='Train', color='blue')
axs[0, 1].set_title("Precision of RNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_rnn)), train_recall_rnn, label='Train', color='blue')
axs[0, 2].set_title("Recall of RNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_rnn)), train_f1score_rnn, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of RNN(from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_rnn)), train_loss_rnn, label='Train', color='blue')
axs[1, 1].set_title("Loss of RNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_rnn)), test_accuracy_rnn, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of RNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_rnn)), test_precison_rnn, label='Test', color='orange')
axs[0, 1].set_title("Precision of RNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_rnn)), test_recall_rnn, label='Test', color='orange')
axs[0, 2].set_title("Recall of RNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_rnn)), test_f1score_rnn, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of RNN (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_rnn)), test_loss_rnn, label='Test', color='orange')
axs[1, 1].set_title("Loss of RNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # LSTM

# %%
train_loss_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/train_loss.pth")
train_accuracy_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/train_accuracy.pth")
train_f1score_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/train_f1score.pth")
train_precision_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/train_precision.pth")
train_recall_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/train_recall.pth")

test_loss_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/test_loss.pth")
test_accuracy_lstm = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/test_accuracy.pth')
test_f1score_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/test_f1score.pth")
test_precison_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/test_precision.pth")
test_recall_lstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/LSTM/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1896645810.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_lstm)), train_accuracy_lstm, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of LSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_lstm)), train_precision_lstm, label='Train', color='blue')
axs[0, 1].set_title("Precision of LSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_lstm)), train_recall_lstm, label='Train', color='blue')
axs[0, 2].set_title("Recall of LSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_lstm)), train_f1score_lstm, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of LSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_lstm)), train_loss_lstm, label='Train', color='blue')
axs[1, 1].set_title("Loss of LSTM (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_lstm)), test_accuracy_lstm, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of LSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_lstm)), test_precison_lstm, label='Test', color='orange')
axs[0, 1].set_title("Precision of LSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_lstm)), test_recall_lstm, label='Test', color='orange')
axs[0, 2].set_title("Recall of LSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_lstm)), test_f1score_lstm, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of LSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_lstm)), test_loss_lstm, label='Test', color='orange')
axs[1, 1].set_title("Loss of LSTM (from ICD to Description))")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # GRU

# %%
train_loss_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/train_loss.pth")
train_accuracy_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/train_accuracy.pth")
train_f1score_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/train_f1score.pth")
train_precision_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/train_precision.pth")
train_recall_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/train_recall.pth")

test_loss_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/test_loss.pth")
test_accuracy_gru = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/test_accuracy.pth')
test_f1score_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/test_f1score.pth")
test_precison_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/test_precision.pth")
test_recall_gru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/GRU/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/4008576357.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_gru)), train_accuracy_gru, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of GRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_gru)), train_precision_gru, label='Train', color='blue')
axs[0, 1].set_title("Precision of GRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_gru)), train_recall_gru, label='Train', color='blue')
axs[0, 2].set_title("Recall of GRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_gru)), train_f1score_gru, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of GRU (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_gru)), train_loss_gru, label='Train', color='blue')
axs[1, 1].set_title("Loss of GRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_gru)), test_accuracy_gru, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of GRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_gru)), test_precison_gru, label='Test', color='orange')
axs[0, 1].set_title("Precision of GRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_gru)), test_recall_gru, label='Test', color='orange')
axs[0, 2].set_title("Recall of GRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_gru)), test_f1score_gru, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of GRU (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_gru)), test_loss_gru, label='Test', color='orange')
axs[1, 1].set_title("Loss of GRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # DeepRNN

# %%
train_loss_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/train_loss.pth")
train_accuracy_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/train_accuracy.pth")
train_f1score_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/train_f1score.pth")
train_precision_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/train_precision.pth")
train_recall_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/train_recall.pth")

test_loss_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/test_loss.pth")
test_accuracy_deeprnn = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/test_accuracy.pth')
test_f1score_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/test_f1score.pth")
test_precison_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/test_precision.pth")
test_recall_deeprnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeeepRNN/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/4044073613.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_deeprnn)), train_accuracy_deeprnn, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of DeepRNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_deeprnn)), train_precision_deeprnn, label='Train', color='blue')
axs[0, 1].set_title("Precision of DeepRNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_deeprnn)), train_recall_deeprnn, label='Train', color='blue')
axs[0, 2].set_title("Recall of DeepRNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_deeprnn)), train_f1score_deeprnn, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of DeepRNN (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_deeprnn)), train_loss_deeprnn, label='Train', color='blue')
axs[1, 1].set_title("Loss of DeepRNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_deeprnn)), test_accuracy_deeprnn, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of DeepRNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_deeprnn)), test_precison_deeprnn, label='Test', color='orange')
axs[0, 1].set_title("Precision of DeepRNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_deeprnn)), test_recall_deeprnn, label='Test', color='orange')
axs[0, 2].set_title("Recall of DeepRNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_deeprnn)), test_f1score_deeprnn, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of DeepRNN (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_deeprnn)), test_loss_deeprnn, label='Test', color='orange')
axs[1, 1].set_title("Loss of DeepRNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # DeepLSTM

# %%
train_loss_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/train_loss.pth")
train_accuracy_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/train_accuracy.pth")
train_f1score_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/train_f1score.pth")
train_precision_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/train_precision.pth")
train_recall_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/train_recall.pth")

test_loss_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/test_loss.pth")
test_accuracy_deeplstm = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/test_accuracy.pth')
test_f1score_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/test_f1score.pth")
test_precison_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/test_precision.pth")
test_recall_deeplstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepLSTM/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1712350040.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_deeplstm)), train_accuracy_deeplstm, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of DeepLSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_deeplstm)), train_precision_deeplstm, label='Train', color='blue')
axs[0, 1].set_title("Precision of DeepLSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_deeplstm)), train_recall_deeplstm, label='Train', color='blue')
axs[0, 2].set_title("Recall of DeepLSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_deeplstm)), train_f1score_deeplstm, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of DeepLSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_deeplstm)), train_loss_deeplstm, label='Train', color='blue')
axs[1, 1].set_title("Loss of DeepLSTM (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_deeplstm)), test_accuracy_deeplstm, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of DeepLSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_deeplstm)), test_precison_deeplstm, label='Test', color='orange')
axs[0, 1].set_title("Precision of DeepLSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_deeplstm)), test_recall_deeplstm, label='Test', color='orange')
axs[0, 2].set_title("Recall of DeepLSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_deeplstm)), test_f1score_deeplstm, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of DeepLSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_deeplstm)), test_loss_deeplstm, label='Test', color='orange')
axs[1, 1].set_title("Loss of DeepLSTM (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # DeepGRU

# %%
train_loss_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/train_loss.pth")
train_accuracy_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/train_accuracy.pth")
train_f1score_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/train_f1score.pth")
train_precision_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/train_precision.pth")
train_recall_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/train_recall.pth")

test_loss_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/test_loss.pth")
test_accuracy_deepgru = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/test_accuracy.pth')
test_f1score_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/test_f1score.pth")
test_precison_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/test_precision.pth")
test_recall_deepgru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/DeepGRU/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1155541245.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_deepgru)), train_accuracy_deepgru, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of DeepGRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_deepgru)), train_precision_deepgru, label='Train', color='blue')
axs[0, 1].set_title("Precision of DeepGRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_deepgru)), train_recall_deepgru, label='Train', color='blue')
axs[0, 2].set_title("Recall of DeepGRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_deepgru)), train_f1score_deepgru, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of DeepGRU (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_deepgru)), train_loss_deepgru, label='Train', color='blue')
axs[1, 1].set_title("Loss of DeepGRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_deepgru)), test_accuracy_deepgru, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of DeepGRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_deepgru)), test_precison_deepgru, label='Test', color='orange')
axs[0, 1].set_title("Precision of DeepGRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_deepgru)), test_recall_deepgru, label='Test', color='orange')
axs[0, 2].set_title("Recall of DeepGRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_deepgru)), test_f1score_deepgru, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of DeepGRU (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_deepgru)), test_loss_deepgru, label='Test', color='orange')
axs[1, 1].set_title("Loss of DeepGRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bi-RNN

# %%
train_loss_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/train_loss.pth")
train_accuracy_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/train_accuracy.pth")
train_f1score_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/train_f1score.pth")
train_precision_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/train_precision.pth")
train_recall_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/train_recall.pth")

test_loss_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/test_loss.pth")
test_accuracy_birnn = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/test_accuracy.pth')
test_f1score_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/test_f1score.pth")
test_precison_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/test_precision.pth")
test_recall_birnn = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiRNN/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1761833558.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_birnn)), train_accuracy_birnn, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of Bi_RNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_birnn)), train_precision_birnn, label='Train', color='blue')
axs[0, 1].set_title("Precision of Bi_RNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_birnn)), train_recall_birnn, label='Train', color='blue')
axs[0, 2].set_title("Recall of Bi_RNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_birnn)), train_f1score_birnn, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of Bi_RNN (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_birnn)), train_loss_birnn, label='Train', color='blue')
axs[1, 1].set_title("Loss of Bi_RNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_birnn)), test_accuracy_birnn, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of Bi_RNN (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_birnn)), test_precison_birnn, label='Test', color='orange')
axs[0, 1].set_title("Precision of Bi_RNN (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_birnn)), test_recall_birnn, label='Test', color='orange')
axs[0, 2].set_title("Recall of Bi_RNN (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_birnn)), test_f1score_birnn, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of Bi_RNN (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_birnn)), test_loss_birnn, label='Test', color='orange')
axs[1, 1].set_title("Loss of Bi_RNN (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bi-LSTM

# %%
train_loss_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/train_loss.pth")
train_accuracy_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/train_accuracy.pth")
train_f1score_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/train_f1score.pth")
train_precision_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/train_precision.pth")
train_recall_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/train_recall.pth")

test_loss_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/test_loss.pth")
test_accuracy_bilstm = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/test_accuracy.pth')
test_f1score_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/test_f1score.pth")
test_precison_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/test_precision.pth")
test_recall_bilstm = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiLSTM/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/4152863960.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_bilstm)), train_accuracy_bilstm, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of BiLSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_bilstm)), train_precision_bilstm, label='Train', color='blue')
axs[0, 1].set_title("Precision of BiLSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_bilstm)), train_recall_bilstm, label='Train', color='blue')
axs[0, 2].set_title("Recall of BiLSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_bilstm)), train_f1score_bilstm, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of BiLSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_bilstm)), train_loss_bilstm, label='Train', color='blue')
axs[1, 1].set_title("Loss of BiLSTM (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_bilstm)), test_accuracy_bilstm, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of BiLSTM (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_bilstm)), test_precison_bilstm, label='Test', color='orange')
axs[0, 1].set_title("Precision of BiLSTM (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_bilstm)), test_recall_bilstm, label='Test', color='orange')
axs[0, 2].set_title("Recall of BiLSTM (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_bilstm)), test_f1score_bilstm, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of BiLSTM (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_bilstm)), test_loss_bilstm, label='Test', color='orange')
axs[1, 1].set_title("Loss of BiLSTM (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bi-GRU

# %%
train_loss_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/train_loss.pth")
train_accuracy_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/train_accuracy.pth")
train_f1score_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/train_f1score.pth")
train_precision_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/train_precision.pth")
train_recall_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/train_recall.pth")

test_loss_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/test_loss.pth")
test_accuracy_bigru = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/test_accuracy.pth')
test_f1score_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/test_f1score.pth")
test_precison_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/test_precision.pth")
test_recall_bigru = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/BiGRU/test_recall.pth")
# Out:
# /tmp/ipykernel_3572274/1776659464.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_bigru)), train_accuracy_bigru, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of BiGRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_bigru)), train_precision_bigru, label='Train', color='blue')
axs[0, 1].set_title("Precision of BiGRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_bigru)), train_recall_bigru, label='Train', color='blue')
axs[0, 2].set_title("Recall of BiGRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_bigru)), train_f1score_bigru, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of BiGRU (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_bigru)), train_loss_bigru, label='Train', color='blue')
axs[1, 1].set_title("Loss of BiGRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_bigru)), test_accuracy_bigru, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of BiGRU (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_bigru)), test_precison_bigru, label='Test', color='orange')
axs[0, 1].set_title("Precision of BiGRU (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_bigru)), test_recall_bigru, label='Test', color='orange')
axs[0, 2].set_title("Recall of BiGRU (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_bigru)), test_f1score_bigru, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of BiGRU (ffrom ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_bigru)), test_loss_bigru, label='Test', color='orange')
axs[1, 1].set_title("Loss of BiGRU (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Transformer

# %%
train_loss_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/train_loss.pth")
train_accuracy_transformer= torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/train_accuracy.pth")
train_f1score_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/train_f1score.pth")
train_precision_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/train_precision.pth")
train_recall_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/train_recall.pth")

test_loss_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/test_loss.pth")
test_accuracy_transformer = torch.load('/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/test_accuracy.pth')
test_f1score_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/test_f1score.pth")
test_precison_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/test_precision.pth")
test_recall_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/test_recall.pth")
test_BLEU_transformers = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/bleu_scores.pth")
test_character_error_rate_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/char_errors.pth")
test_word_error_rate_transformer = torch.load("/home/careinfolab/Dr_Luo/Rohan/ICD_Codes/Results/ICD_to_Desc/Transformer/word_errors.pth")
# Out:
# /tmp/ipykernel_3572274/585032568.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(train_accuracy_transformer)), train_accuracy_transformer, label='Train', color='blue')
axs[0, 0].set_title("Accuracy of Transformer (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(train_precision_transformer)), train_precision_transformer, label='Train', color='blue')
axs[0, 1].set_title("Precision of Transformer (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(train_recall_transformer)), train_recall_transformer, label='Train', color='blue')
axs[0, 2].set_title("Recall of Transformer (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(train_f1score_transformer)), train_f1score_transformer, label='Train', color='blue')
axs[1, 0].set_title("F1 Score of Transformer (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(train_loss_transformer)), train_loss_transformer, label='Train', color='blue')
axs[1, 1].set_title("Loss of Transformer (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

axs[0, 0].plot(range(len(test_accuracy_transformer)), test_accuracy_transformer, label='Test', color='orange')
axs[0, 0].set_title("Accuracy of Transformer (from ICD to Description)")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

axs[0, 1].plot(range(len(test_precison_transformer)), test_precison_transformer, label='Test', color='orange')
axs[0, 1].set_title("Precision of Transformer (from ICD to Description)")
axs[0, 1].set_ylabel("Precision")
axs[0, 1].legend()

axs[0, 2].plot(range(len(test_recall_transformer)), test_recall_transformer, label='Test', color='orange')
axs[0, 2].set_title("Recall of Transformer (from ICD to Description)")
axs[0, 2].set_ylabel("Recall")
axs[0, 2].legend()

axs[1, 0].plot(range(len(test_f1score_transformer)), test_f1score_transformer, label='Test', color='orange')
axs[1, 0].set_title("F1 Score of Transformer (from ICD to Description)")
axs[1, 0].set_ylabel("F1")
axs[1, 0].legend()

axs[1, 1].plot(range(len(test_loss_transformer)), test_loss_transformer, label='Test', color='orange')
axs[1, 1].set_title("Loss of Transformer (from ICD to Description)")
axs[1, 1].set_ylabel("Loss")
axs[1, 1].legend()

axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))  

axs[0].plot(range(len(test_BLEU_transformers)), test_BLEU_transformers, label='Blue Error', color='blue')
axs[0].set_title("Blue Error of Transformer (from ICD to Description)")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Error")
axs[0].legend()

axs[1].plot(range(len(test_word_error_rate_transformer)), test_word_error_rate_transformer, label='Word Error', color='green')
axs[1].set_title("Word Error of Transformer (from ICD to Description)")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Error")
axs[1].legend()

axs[2].plot(range(len(test_character_error_rate_transformer)), test_character_error_rate_transformer, label='Character Error', color='red')
axs[2].set_title("Character Error of Transformer (from ICD to Description)")
axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Error")
axs[2].legend()

plt.tight_layout()
plt.show()
